# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np


# data I/O
data = open('nescio.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print ('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)

  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 202367 characters, 89 unique.
# ----
#  ê/7wûi4rInjJF1rb'A2.ZtdPï)K3svIEHO.SïvüvbqcV,UüqxIJ.Gjêu4áá6)3üawKèEë,'v3 ïátj5pcê?(vSB8H
# tV.ïàD2éPX2fkdF
# l"N hék5'é.8kC25WA0PbvE73b"48péZjqè5ll3u6xg1MX 3()âLëZ)éïpiKKr7ô0I3UnJF-4ò5Pjês."iA;ëI,GDtC(u3
# ----
# iter 0, loss: 112.215912
# ----
#  ratknS.a.maaH 2er e z t vauir s p oke z a k H odj n jeoo  eaeôeks " l f o dejáj Brrwinlde o z ddpke ekekhloaj r âtd jrh  u) tgHvvepaw H
# o hapPu grj 'a. eFdrl .r" n8hkGr
#  narkk sa1E ea jtjae s o w do.a
# ----
# iter 100, loss: 112.741927
# ----
#  aPnpknee  du ro
# âcanteshnentan:zhl w,eaeuta n  nVlai  toeeai edireoas,nk dnL di ionoimrm  esslmfndded onkknWkginDot iedd èiralwldejr edt
# Vnu lculjnteveiEsei i ididoee k  eaao sein ri otwln u n nw en
# ----
# iter 200, loss: 109.937558
# ----
#  rnxntnda zteenened taj eabejs s ar l psetuieaarowete lantk n r,n
# zio-zaree  k .cflee nhi i Ton gopLb iazanoedljl
# rt diei  de t'ots ud  l,wtoe oJenait dloreegj  h
# ,l
# n'ceâuzte snoti iandowe nan rhnlvan
# ----
# iter 300, loss: 107.073160
# ----
#   cofretzoln
# etet eaen oi  chtirht stej hee laind,ol
# at ucheo  t çi ieeeo nrreô"on  ent.seeee
#  ,re wyehitoet xg sviae.rer'nede peët. leeeEvateeegtieaandmeoefe v eeesiogh've d eezerlzma htaiag
# wi letLl
# ----
# iter 400, loss: 104.335324
# ----
#  ewtes ot vienm tan h ead ean ed wmdrslll waeAohekhei,  snagoOtaislaor zahe,oae emn
# Derde eaos EhGdrma ot  reretem dnn enr worn,ed it cKu eknan  hen okpe d  ooVi zagev rae
# ."  âgei we
# ioeui  etear .oa
# ----
# iter 500, loss: 101.425574
# ----
#  esctr.umKnen
#  Heed sns
# oeog /je hihnr atese hioc, wa
# dn pte tet zanordndJrerkszekRmaelr.e np,decZn
# Dln tan
# glvaunsrnn maos vaelann oint en tvrme vFkek
# ne hoakn  eleotedr lian wkn sx datnes eede ze c s
# ----
# iter 600, loss: 98.556218
# ----
#  Hiy, ht eolerini,d
# wDeektthd 3er vrng men ntr senerdie
# de hn. pl. w
# itin.ee dn  mt zkkn t daa iarvnjee ,
# s,d hsn ret dmoGnlkel leri RerteoinnCte dienTnzdt bn
#
# zkrcvn ume jahgldn gttf jn oôn eeed't  h
# ----
# iter 700, loss: 95.742887
# ----
#  Onele dueian veiare omeee svo
# , mamat lerp ene ea Ean hNmeontoa'le zoigereteeoidt zemeg naaa hweaachEnn mreid ielegr  meme entjaa h deejrdree teiria, zand, ieot hiarlaan
# , ian iede  me
#  gooai zege, z
# ----
# iter 800, loss: 93.056057
# ----
#  alj vaern gee er zone meot
# twn oo hel hoalnent al dan haar zotn vt wen neen hea
# kawn en g'r zpm, n zeeO Eovet dehbig ean rhaot rsr terk vrng ear.
# 'eleetk hallen
#  éar vaer hon roan maaa keim kee oe. ht
# ----
# iter 900, loss: 90.604598
# ----
#  .ar dottjekbel t ait zeok heen wuooe Dengrvaoobt , vaa.sui dt Maat tteknfaan Hai n neije  dt zle eat iitrigrjrmn,e wmalr.edi.
# hen 'u. dajtrarr k'ar domeme eue, bode "tau
# mardje dioge, ia
# tLtualrtome.
#
# ----
# iter 1000, loss: 88.102215
# ----
#
# mge e'V.htwotve esgas dwjlhoer .ts ehlask dasser vererwar,epijen mekt i
# en girig weuani die brodnlee weer.
# Rej oe .e
# bGopc'e hael  iaêgensa
#  zceweo Daun 't gitednke daa ban voaaj eem, geor haulbian
# ----
# iter 1100, loss: 85.891690
# ----
#  en en bjd,
# 'n çjnjes" ooe han daopripdnep ie aasza heetd ers suima
# Lgn baet mou ten eet vipiedmo"cTVa ettarits 't vn ar " has cnren en hes arojj deets hwal rarin 'n ziarasjen wiat dault darsn honian
# ----
# iter 1200, loss: 83.764936
# ----
#  d der ' bpszier bom elijeeeen aof zoaje andjmeorge
#  Gndirdanmesad eoM ooj kan aom wadnmmarvud zit doegs wkom bnoouw auenduon getechlamiretoSirlaam oe bien nate,euerjerhaohtde zen hooNm voet berog beer
# ----
# iter 1300, loss: 81.868940
# ----
#  tou vielina
# ren vmige ien ernnlaat terhar wiefl zi"tn hnoor vles gent Maaer ian eaide :djn ges ve zovaa nteng , re ior ar en sp bi  f veoer bodka wae desnaap. we dandk rae der t vaen Dat
# teen den aer
# ----
# iter 1400, loss: 79.827843
# ----
#  eat 'tt en zocg dee Eraane meas de ve dbte, hat gan ege koon
# we kegdee, en hai ns et 2alkzaacht verdeer 'r  zp hiar it "
# aegjos Horot et zetiglanpetduek vachas, sn ivop, :pdinaren  en epd op venrwrlaa
# ----
# iter 1500, loss: 77.965055
# ----
#  tuen
# baon éen  nWeen hie heilon lichden bals aoeek haendfzlgnes ien van Daj, doenjen er dlinwarde bi
# heen ade diodnep
# , Dit koerHerilejf kien, hes. s" djon. dooren Huzie nererr in ge enlwit ze hoop,
# m
# ----
# iter 1600, loss: 76.320876
# ----
#   s'cprner el ,.. keenlkzee
# rGagen !atd widan, depefn eetreon. Vnd zeedt kaen zin, hanst veen in kenenetdeerdopendecmn ou Bo-.toe lil" fek mais lonn tlie direriete wit kn stijndieretgoowmaanson at dakd
# ----
# iter 1700, loss: 74.940493
# ----
#  Felkeesin 't diveep ee 'e ve-ichtitawagengelon et ool.den atn nudijmdes. It
# ala detel.gen engdbeegendeetrerdrartwjn bje. vo, zeen dokden, stiep bekt eenrepvat 'n ovegsje moaaensginnen el bn
# dej vee  z
# ----
# iter 1800, loss: 73.350258
# ----
#  zpe bovaa n eër weede den zeel s'n liar e in wi den n
# oan 't soentat be de te are zoer zasd der el er e di tekden
# échtard ins Vadtk etecn, :e men dinudaj aan 'cn oir ivenrfenysen mohttjs, vai lan. din
# ----
# iter 1900, loss: 71.933471
# ----
#  n tiev hgails ins rghaoh magn kent merNe voe hzeeg dokig as di dens
# -oe koh 't ter be dia dien oe eentig
# on dok moopeklwokachvorvachant dien
# ou de hac wat htger, hoeteinik gove h inngerretkweg
# ivottj
# ----
# iter 2000, loss: 70.867388
# ----
#  nair vear
# miet, daltes ar ven waar num hinen defwap. he di hbas Daofden
# Noe.l iiC doeren olt gerelerop sjoen. er deedjeg en wae noen,t kvreent veen elJait frgof, malit vaate;dt zin
# taar ep er haakren
# ----
# iter 2100, loss: 69.845040
# ----
#  dude we it han, gejde reigure teudeg zops, zovarocht wotdaleruio kenen waar en natevon gekger el Bek.kPëC, hid zjenen litsvon ti lijdenjen en venopdeks'ngitge sapn ooregcg dij é'nlop ?in kleI-tjem.al
# ----
# iter 2200, loss: 68.655608
# ----
#  jf en gad en esfnoneg ecstdtwat de hoort er zinchent suten."Tijs hangn.ofl tnij dijere hen. Daurden kijt has enije hanff oi haar llom 't stben eny haas.
# dws heerruoh.. kijk or ze enteveret. Diri te di
# ----
# iter 2300, loss: 67.535660
# ----
#  endan in zvamt en el her arugiepk
# es zicijoniten og gestonger naas wen s
# dar Er emche zoenraar zhait hschtee helri stter oer En wohechsarde biihst hoovzen heoriehbard
# laarlaig sint nar ben ten.
# éE haa
# ----
# iter 2400, loss: 66.632609
# ----
#
# Al viobin.
# ò Miarre ze en,
# selkegen zooede geen miel mo de zoe zeenwelen wijn kin te wooomoengen zef vo hen geug rep algerdi
# fdel nnlier des
#
# zengen vmesteeen hau schdar zeg, necMenzoer, Bord, hakgge
# ----
# iter 2500, loss: 65.670440
# ----
#  wten hoodeonie haanlaliu maat s in dijemelaatenrdenRraaer has telset han elijn derran ze en hezede inl Doptme. stret d wowdjan zolast oeon Wal ste za
# ten kijst, injgentder . Er ronmrdat en tel ef,
# kan
# ----
# iter 2600, loss: 64.710874
# ----
#   noergolee zan
# 'n de, vig an En ons tooraar zok en er: Eek and. voel Zan ween dijn en epn st int 't vek tike
# kukme zeen net z't de mecf, deonden
# was 'h in wui zaard loste det, bij en od én Der al din
# ----
# iter 2700, loss: 63.768476
# ----
#  ngjin jn
# gor osus saar htoer ki toourtgen
#  Gamjogeen zovat oCuen zestem, zin teen moerdejen he kuik eas hesonererenn een soed He heo
# as ees dokVer wou hanfijerwnuitre tan de pagratk," hp wig erllijr e
# ----
# iter 2800, loss: 63.114698
# ----
#   laan bkin komene valen gal zplevejn par kien zat zaher haarlan wan zie zijsgloar jan warkon nvaal heg hoopen Ochte s"walst hs em En 't dlolu Oin tenAn h
# hig or ge ete nelat hein win en zoe elesgendin
# ----
# iter 2900, loss: 62.519088
# ----
#  tp hjet.
# htelje en mien epterlenderkjoligmuolkistiemenneen.
# "ç
# vref kooer ge hog 'n delwan vin d ddoonke w? kene"
# er, vaar 't vasc't ahenleen vas dichtain
# varusttiekteranglert, vijk zigen, wigbes
# lt.
# ----
# iter 3000, loss: 62.100649
# ----
#   baar anl jle hesgoof v zool eit heek."
# Mostwauldinjan aanre zoede 't zrimge lpowenranstarde, teen. Ecliap heel bele nachteprin
# ke .
# loestertat, daws saar hies vande rekaal dan la tes waar we ahemgege
# ----
# iter 3100, loss: 61.411406
# ----
#  onwau.
# .
# Zwerdirrtekd geraaar teldat geverijleerster.m.d mdende ok am stomt en bajl, heren dichiorevmainâ.g en
# vaul zaltrast. werat kas. de
# haaizen Saldraar tan.pDoo ent "amaef ,lkretvokgcppjepgerijn
# ----
# iter 3200, loss: 61.235208
# ----
#   Etsn vintede zoiustaar vanme nen get olumerf. Z't ascon keer Ga kegoedeem en ee i Een. Zandoo hede
#
# a
# st en, eroin valijtten.
#
# Ii ee. ent zij watelen Touneete saude das en.
# Be ek beet inder vaan
# zij
# ----
# iter 3300, loss: 61.323363
# ----
#  hen ik inl it. Nolderzoggein wil. Darwik, diat maatirf ier. En "Bn
# an, te naed. Daan Veend ep ou
# :I
#
# waar sdijk
# .
#
# Loe. talke haad, wande. Eveer. Te olcnjn door
# dan pin hooverlacherd. Te il op. Wpen o
# ----
# iter 3400, loss: 61.061504
# ----
#  ijk in  'n wim at wain aankerde onken bige rit nueren hoeds keeten wajr 'd de net eend, difd voekwaart, tan. Zig em maraarve"terijik.
#  Zolees. laids en ik "
# retVan
# je zaar
# paan kpen z'n noefken "t gil
# ----
# iter 3500, loss: 60.805497
# ----
#  n
# weepn
# arees
# vold Tmeen l't walterant Fbast zat bamnvat kna:djten heleellumeen at aal.
#
# "oe ver 'n ken-cht?
# wohmaat en
# nluafin zik zeik zoedent ban woovwahran wingdt kergenkuringen veer wieukan vad w
# ----
# iter 3600, loss: 60.459474
# ----
#  f. "Meel. Gud Paan
# Ben deeden
# vanren.Jf op toelt en ich ur zig je 't kaan Boud alte las de
#
# ol ved ie haar Jant en de op kooe stohee Bem lane nwde waneschoeen alelwei ingta ie , ol je
# Dar, ?nas elen
# ----
# iter 3700, loss: 59.888448
# ----
#  ede ben elt hou mincht aonn han in den en. Dut nin van zicht wonkd doat aninenij lopztoeklen pendeenanschsgin haakrao.. De schteen
# zicht wog ivd toakun, raan uaarije veila
# uiens de lochten aon tenijen
# ----
# iter 3800, loss: 59.561715
# ----
#  anij kensteen den ne denste de
# has
# aBomdzende. Jalsearder dicle iven gerijnt gopBer sen zet Bamngerprat ep naar verkve ragr Bacht open vakwaan en ke"kon gependen iun set taarinden wpij, zoe waatte. In
# ----
# iter 3900, loss: 59.242515
# ----
#
#  ?i amien noen ?at Tidbig di vien.
# st samenr ent apsmest Mooongen, ze lagel ''nrij ent kapst. Zes kie kovinkdletenscmen di;n schuurzui; oogen werkmteiarden,
# st. hnots, de tf terieven llchit buster ru
# ----
# iter 4000, loss: 59.113723
# ----
#  ar zen huot nievmaat. 'mervat nge wijtien. Hèvonbers be noes nies, "listeen. En storkejr 'tdersk zig "raacheer inen" bites laar sterde ri dan hij noer. 3it zij Bat ep, dpeg zant laeivam 'te" Janraar w
# ----
# iter 4100, loss: 59.197662
# ----
#  , apoogers waltassruik an hes koekelpas degmopel jen lajkten Bas zonden movep en danken reerre in diénst pncn gen. Zu blikker.
#
# ga", wierer ker"gamens ziiet en t
# hater dan st me pechij, ijnoit er geId
# ----
# iter 4200, loss: 59.221614
# ----
#  n, beilij taps, klerit kwam das dan tan deg die bed Velij
# end mesterlapren as kij mati lukel liid sgend emenvordendie dan hijl el een orest 'ds lad voo"ten moe minkbieni daprei agsehejp, we dijentan k
# ----
# iter 4300, loss: 58.978284
# ----
#  lkien wak goors "3oet
# nei lalmi leij.
# p "Loe, ze tid. Ze koelk,
# ak boar i heignpanudrwit hed, "'t jis haanden maglwauk. "aqkijnzogrene hkiewrcvenen benond sGbmen't in moedt. Juns, vins, saum alvi duaf
# ----
# iter 4400, loss: 58.800752
# ----
#  ke redusteer daiven zaten "aer en stereer en weren am dachten wanvend, nat werkele, spelje op mijt on zak gerij gr'n steerien det zan zet hat 't biegred wat olk korbeinst. "I zezoes:
# En zak oot Hachpa
# ----
# iter 4500, loss: 58.996799
# ----
#   Al jen Ne nas dan ek en je bit el, geverdem
# Ittcp, destes ze dau das dam Len tetteen geveper i dend wand stomer zeen kooer.en dendef von kan wastenerls dit zog il 'n hielen apwek" zZaar, omeres padsa
# ----
# iter 4600, loss: 58.793945
# ----
#  on dil ji et Hwag noer vecstelen et
# i 'n mene zemde genahs or oop valdee! pleen iden stilde dier lijn ep ik Das rij: heten zieg hendak bune rager,
# "wee pae wakensnoptet me doordje,
# Jaan stee. En
# or zi
# ----
# iter 4700, loss: 58.495427
# ----
#  wou zeeen.l Tar een d'n meer. Hino ziiker dape ijé zecht ze or en ven van schij ste kpatiel kide hapen s?
# bak dierkers, zee lon kelbep vetdracht, moo nrel vait bie kvop pechintjn
# ziel at re
# die zeegek
# ----
# iter 4800, loss: 58.330562
# ----
#  s zurgen
# at ber emeen kgel. Eflech Toet pijk vi Zaat vank?s b't s'n  ik elm en CKzonjer Boude m'n 'te
# leren zie "hogi vaaC.. Ar dar. Hiel nag er en beuiV, waniem en var Bot mas saar :iegt vor vansme"s
# ----
# iter 4900, loss: 58.054259
# ----
#   kllieur hied zosten doondernie ivelel kafr. Aal awim el ik
# woon iik beki
# laan, zook hoereg , 't mooke tousgeld oe gen men vig mrekude gook. Din op de men viekt Den denin inten lan meerkius zohs maar
# ----
# iter 5000, loss: 57.888004
# ----
#  n. Haanen gnascti ""'t bahzik mee kes zij wiekberidzest den mier is heijg van jinn be dejn blenmendvak ik.
# "Dinken tenkze hen geer nat buik se'n h't, Zefen elwehent ik te bigpen ui baadde hijk voeveli
# ----
# iter 5100, loss: 57.620048
# ----
#  p hveg wals
# Amorgie beg hegerik dee
# ?rohzadr lorseho Je
# hie zits. JJdlen. I zacl. Ik werhanr wen im arnade nadik teP pie sét. 't dijn er en ziesgijdeF ae gendenijst wig, en niet heg sans steenneme k,
#
# ----
# iter 5200, loss: 57.523150
# ----
#   hropt daen zeewan ir pooen ranliet i teel, aar wiet den Daan rakgensorift womoer. Dareen kas in ginde genielvoert enhou henden ""hchij haand. Waar, en dak Jat z's on dog dan geenteen. Den anem In kon
# ----
# iter 5300, loss: 57.314558
# ----
#  ij st weetin de al'nichtem klan en oen Ean "Wehiewan vaun Mie d du
#  de zaldaels, zoig m0ogeen
# or
# zoon drscm hen dist ten warijen den warij st vi Mafdl
# el zen mrgor
# hoe
# ten oon men altad ofen. Daneten.
# ----
# iter 5400, loss: 57.025374
# ----
#  't aAd i. 1ëre beaps, hon érot galohteen oebege die wi. haanstanijchamtoo,
# áeel oevnomder keste
# ere 'n. Del van vian dasch, en schi wavinlers
# vaplel.k
# joet Jegeild vaafle et was kon zeen big8vand mete
# ----
# iter 5500, loss: 56.938268
# ----
#  an." Il wig hat goui vi woed au" zij pij ak ien zojste mem gehas zij, wal zed en brsTaid waat hat in ie?,
#  Hacher uibder ter,
# en oe robker ik
# fatdian boe kada, wamgeal lastjken paar en eraop ve naerbe
# ----
# iter 5600, loss: 56.877042
# ----
#  n joorieken dezelke i he vi ze kegroufkrakchteren enn te was tu, de ven le har hijn gelden wijemiet. Jan. 't
# Em en staan je Jn hijn ver eten. Di order jog ai ken rasteninhi terram. Oaken 't kom en wa
# ----
# iter 5700, loss: 56.747361
# ----
#  er
# apan dstgegliastenlien mizwelde miipgen dan. Hie in
# er ze tord, das en noog keruu
# geraar hen
# genknefpome doptavem wamouft on rijteHbeven ep saarae oren. "Ze if en hovel zij de tacht weig'n
# de weg e
# ----
# iter 5800, loss: 56.645684
# ----
#  d not kroeden ment susteen virderen. wat Prie wooeden in dien ten zaden ven. genlig oe hantei Fbgensten Homens bonderener'ts zees noeint scbfe lat bibreer Bagkent en we nug van el. Dar wie ween lui he
# ----
# iter 5900, loss: 56.630075
# ----
#   ar kun st dat haar rozterien ('n in aasten a hen gepen ket woen zaat asid de en. Holreed ved den zei benHeed zoes tooken genda, nit er wau rorken
# pamet de neg en. IO van biwPar meusijr zeend vek bei
# ----
# iter 6000, loss: 56.303258
# ----
#  doafl bezeer gie 'hvien.
#
# Bpall ik scSderijstelen gede sasirende nan stanen zen
# duen en bemen zet inist den cme geot nigles engen. Hind,
#
# "Euken. Walde narzon
# geetree zood al nodkerste ortiebleinveen
# ----
# iter 6100, loss: 56.255691
# ----
#  afsteldeen mad aal dind, gelde(, kendienaen gelie hie. Ear voek zen hen, wa laaf schourdden
# dijk racot en arkeen he heweks Zoor el gad ik le 'p or et beh z'tboon han urtoen en mee gewajfje zat g, aabr
# ----
# iter 6200, loss: 56.244364
# ----
#  d veed te
# un wij vijk aevit nusteen en 't stakeen, zeg vin gevsgen. Test woopdou't ald det nijn een nugen
# serret daakan 'k
# Heolk lad k'n mrienwaamgepiar,
# sterjen, vat am pat
# ween geen ek en er on aalk
# ----
# iter 6300, loss: 55.832727
# ----
#  rovenstijgi met deg walien goeten hoe en faschde evrin, ze Joed 'n aar, ed
# scht an min st mees eap. IûDe, i muaan viesten- horden Nuj ze en bek nachten
# doonker tak zoj wej Grde wan. bniet irde on Buié
# ----
# iter 6400, loss: 55.708536
# ----
#  den zigver. Wa
# weé
# halt de foo je erliem aal worver? 't
# op keg., 't de;
# aaind oulkanoe hen." Ze hinkgg hieb mooler
# 't kiit nutwar dnde aat nan hij alte,d
# en
# diem laar ve d, kende nen 't de im m'j en a
# ----
# iter 6500, loss: 55.541145
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-43027b139a9a> in <module>
#      99
#     100   # forward seq_length characters through the net and fetch gradient
# --> 101   loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#     102
#     103   smooth_loss = smooth_loss * 0.999 + loss * 0.001
#
# <ipython-input-2-43027b139a9a> in lossFun(inputs, targets, hprev)
#      57     dWxh += np.dot(dhraw, xs[t].T)
#      58     dWhh += np.dot(dhraw, hs[t-1].T)
# ---> 59     dhnext = np.dot(Whh.T, dhraw)
#      60   for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
#      61     np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
